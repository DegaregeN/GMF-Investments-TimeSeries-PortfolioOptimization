# %%
import yfinance as yf
import pandas as pd

# %%
def download_data(ticker, start_date='2015-01-01', end_date='2024-10-31'):
    """Download historical financial data from YFinance."""
    data = yf.download(ticker, start=start_date, end=end_date)
    data['Ticker'] = ticker
    return data

def main():
    assets = ['TSLA', 'BND', 'SPY']
    all_data = []

    for ticker in assets:
        data = download_data(ticker)
        data.to_csv(f'../data/raw/{ticker}_data.csv')  # Save raw data

if __name__ == "__main__":
    main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Reading of TSLA data

# %%
# Load Tesla dataset
df_tesla = pd.read_csv('../data/raw/TSLA_data.csv')

# %%
df_tesla
# Out:
#                           Price           Adj Close               Close  \
# 0                        Ticker                TSLA                TSLA
# 1                          Date                 NaN                 NaN
# 2     2015-01-02 00:00:00+00:00  14.620667457580566  14.620667457580566
# 3     2015-01-05 00:00:00+00:00  14.005999565124512  14.005999565124512
# 4     2015-01-06 00:00:00+00:00  14.085332870483398  14.085332870483398
# ...                         ...                 ...                 ...
# 2471  2024-10-24 00:00:00+00:00   260.4800109863281   260.4800109863281
# 2472  2024-10-25 00:00:00+00:00  269.19000244140625  269.19000244140625
# 2473  2024-10-28 00:00:00+00:00    262.510009765625    262.510009765625
# 2474  2024-10-29 00:00:00+00:00   259.5199890136719   259.5199890136719
# 2475  2024-10-30 00:00:00+00:00  257.54998779296875  257.54998779296875
#
#                     High                 Low                Open     Volume  \
# ...

# %%
# Dropping 1st two rows by index
indexes_to_drop = [0, 1]  # Specify the row indices to drop
df_tesla = df_tesla.drop(indexes_to_drop)

# %%
# Renaming a Price with date
df_tesla = df_tesla.rename(columns={'Price': 'Date'})
df_tesla
# Out:
#                            Date           Adj Close               Close  \
# 2     2015-01-02 00:00:00+00:00  14.620667457580566  14.620667457580566
# 3     2015-01-05 00:00:00+00:00  14.005999565124512  14.005999565124512
# 4     2015-01-06 00:00:00+00:00  14.085332870483398  14.085332870483398
# 5     2015-01-07 00:00:00+00:00  14.063332557678223  14.063332557678223
# 6     2015-01-08 00:00:00+00:00  14.041333198547363  14.041333198547363
# ...                         ...                 ...                 ...
# 2471  2024-10-24 00:00:00+00:00   260.4800109863281   260.4800109863281
# 2472  2024-10-25 00:00:00+00:00  269.19000244140625  269.19000244140625
# 2473  2024-10-28 00:00:00+00:00    262.510009765625    262.510009765625
# 2474  2024-10-29 00:00:00+00:00   259.5199890136719   259.5199890136719
# 2475  2024-10-30 00:00:00+00:00  257.54998779296875  257.54998779296875
#
#                     High                 Low                Open     Volume  \
# ...

# %% [markdown]
# ## Reading of BND data

# %%
# Load BND dataset
df_BND = pd.read_csv('../data/raw/BND_data.csv')

# %%
df_BND
# Out:
#                           Price           Adj Close              Close  \
# 0                        Ticker                 BND                BND
# 1                          Date                 NaN                NaN
# 2     2015-01-02 00:00:00+00:00    63.3587646484375   82.6500015258789
# 3     2015-01-05 00:00:00+00:00     63.542724609375  82.88999938964844
# 4     2015-01-06 00:00:00+00:00  63.726715087890625  83.12999725341797
# ...                         ...                 ...                ...
# 2471  2024-10-24 00:00:00+00:00   73.08118438720703  73.30999755859375
# 2472  2024-10-25 00:00:00+00:00    72.9316635131836  73.16000366210938
# 2473  2024-10-28 00:00:00+00:00    72.8419418334961  73.06999969482422
# 2474  2024-10-29 00:00:00+00:00   72.90174865722656  73.12999725341797
# 2475  2024-10-30 00:00:00+00:00   72.83197021484375  73.05999755859375
#
#                    High                Low               Open   Volume Ticker
# ...

# %%
# Dropping 1st two rows by index
indexes_to_drop = [0, 1]  # Specify the row indices to drop
df_BND = df_BND.drop(indexes_to_drop)

# %%
# Renaming a Price with date
df_BND = df_BND.rename(columns={'Price': 'Date'})
df_BND
# Out:
#                            Date           Adj Close              Close  \
# 2     2015-01-02 00:00:00+00:00    63.3587646484375   82.6500015258789
# 3     2015-01-05 00:00:00+00:00     63.542724609375  82.88999938964844
# 4     2015-01-06 00:00:00+00:00  63.726715087890625  83.12999725341797
# 5     2015-01-07 00:00:00+00:00   63.76504898071289  83.18000030517578
# 6     2015-01-08 00:00:00+00:00    63.6653938293457  83.05000305175781
# ...                         ...                 ...                ...
# 2471  2024-10-24 00:00:00+00:00   73.08118438720703  73.30999755859375
# 2472  2024-10-25 00:00:00+00:00    72.9316635131836  73.16000366210938
# 2473  2024-10-28 00:00:00+00:00    72.8419418334961  73.06999969482422
# 2474  2024-10-29 00:00:00+00:00   72.90174865722656  73.12999725341797
# 2475  2024-10-30 00:00:00+00:00   72.83197021484375  73.05999755859375
#
#                    High                Low               Open   Volume Ticker
# ...

# %% [markdown]
# ## Reading of SPY data

# %%
# Load SPY dataset
df_SPY = pd.read_csv('../data/raw/SPY_data.csv')

# %%
df_SPY
# Out:
#                           Price           Adj Close               Close  \
# 0                        Ticker                 SPY                 SPY
# 1                          Date                 NaN                 NaN
# 2     2015-01-02 00:00:00+00:00   173.1737823486328  205.42999267578125
# 3     2015-01-05 00:00:00+00:00  170.04629516601562  201.72000122070312
# 4     2015-01-06 00:00:00+00:00   168.4446258544922  199.82000732421875
# ...                         ...                 ...                 ...
# 2471  2024-10-24 00:00:00+00:00    579.239990234375    579.239990234375
# 2472  2024-10-25 00:00:00+00:00   579.0399780273438   579.0399780273438
# 2473  2024-10-28 00:00:00+00:00   580.8300170898438   580.8300170898438
# 2474  2024-10-29 00:00:00+00:00     581.77001953125     581.77001953125
# 2475  2024-10-30 00:00:00+00:00    580.010009765625    580.010009765625
#
#                     High                 Low                Open     Volume  \
# ...

# %%
# Dropping rows by index
indexes_to_drop = [0, 1]  # Specify the row indices to drop
df_SPY = df_SPY.drop(indexes_to_drop)

# %%
# Renaming a Price with date
df_SPY = df_SPY.rename(columns={'Price': 'Date'})
df_SPY
# Out:
#                            Date           Adj Close               Close  \
# 2     2015-01-02 00:00:00+00:00   173.1737823486328  205.42999267578125
# 3     2015-01-05 00:00:00+00:00  170.04629516601562  201.72000122070312
# 4     2015-01-06 00:00:00+00:00   168.4446258544922  199.82000732421875
# 5     2015-01-07 00:00:00+00:00   170.5436553955078  202.30999755859375
# 6     2015-01-08 00:00:00+00:00  173.56991577148438  205.89999389648438
# ...                         ...                 ...                 ...
# 2471  2024-10-24 00:00:00+00:00    579.239990234375    579.239990234375
# 2472  2024-10-25 00:00:00+00:00   579.0399780273438   579.0399780273438
# 2473  2024-10-28 00:00:00+00:00   580.8300170898438   580.8300170898438
# 2474  2024-10-29 00:00:00+00:00     581.77001953125     581.77001953125
# 2475  2024-10-30 00:00:00+00:00    580.010009765625    580.010009765625
#
#                     High                 Low                Open     Volume  \
# ...

# %% [markdown]
# ## Merging of the three datasets

# %%
final_df = pd.concat([df_tesla, df_BND, df_SPY], ignore_index=True)

# %%
final_df
# Out:
#                            Date           Adj Close               Close  \
# 0     2015-01-02 00:00:00+00:00  14.620667457580566  14.620667457580566
# 1     2015-01-05 00:00:00+00:00  14.005999565124512  14.005999565124512
# 2     2015-01-06 00:00:00+00:00  14.085332870483398  14.085332870483398
# 3     2015-01-07 00:00:00+00:00  14.063332557678223  14.063332557678223
# 4     2015-01-08 00:00:00+00:00  14.041333198547363  14.041333198547363
# ...                         ...                 ...                 ...
# 7417  2024-10-24 00:00:00+00:00    579.239990234375    579.239990234375
# 7418  2024-10-25 00:00:00+00:00   579.0399780273438   579.0399780273438
# 7419  2024-10-28 00:00:00+00:00   580.8300170898438   580.8300170898438
# 7420  2024-10-29 00:00:00+00:00     581.77001953125     581.77001953125
# 7421  2024-10-30 00:00:00+00:00    580.010009765625    580.010009765625
#
#                     High                 Low                Open    Volume  \
# ...

# %%
final_df.to_csv('C:\\Users\\1221\\Desktop\\Acadamy AIM 2\\GMF-Investments-TimeSeries-PortfolioOptimization\\data\\raw\\combined_data.csv', index= False)
